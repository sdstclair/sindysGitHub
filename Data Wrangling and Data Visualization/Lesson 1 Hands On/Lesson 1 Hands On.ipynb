# %%
import pandas as pd

# %%
FakeNews = pd.read_excel('C:/Users/HP/Documents/Education/Other/Entity Academy/Data Wrangling and Data Visualization/FakeNews.xlsx')

# %%
FakeNews['StoryType'] = 'Fake'

# %%
FakeNews.drop(['when'], axis=1)
# Out:
#                                                     url  \
# 0     http://wayback.archive.org/web/20161004072420i...
# 1     http://wayback.archive.org/web/20161004072420i...
# 2     http://wayback.archive.org/web/20161004072420i...
# 3     http://wayback.archive.org/web/20161004072420i...
# 4     http://wayback.archive.org/web/20161004072420i...
# ...                                                 ...
# 3334  https://www.ncscooper.com/transgender-dog-unsu...
# 3335  https://www.ncscooper.com/transgender-dog-unsu...
# 3336  https://www.ncscooper.com/transgender-dog-unsu...
# 3337  https://www.ncscooper.com/transgender-dog-unsu...
# 3338  https://www.ncscooper.com/transgender-dog-unsu...
#
#                              tracker StoryType
# 0                        DoubleClick      Fake
# 1                         RevContent      Fake
# 2                        DoubleClick      Fake
# 3                 Google Syndication      Fake
# 4     DoubleClick Ad Exchange-Seller      Fake
# ...

# %%
FakeNews1 = FakeNews['url'].str.split('_/', expand=True)

# %%
FakeNews1
# Out:
#                                                       0  \
# 0       http://wayback.archive.org/web/20161004072420id
# 1       http://wayback.archive.org/web/20161004072420id
# 2       http://wayback.archive.org/web/20161004072420id
# 3       http://wayback.archive.org/web/20161004072420id
# 4       http://wayback.archive.org/web/20161004072420id
# ...                                                 ...
# 3334  https://www.ncscooper.com/transgender-dog-unsu...
# 3335  https://www.ncscooper.com/transgender-dog-unsu...
# 3336  https://www.ncscooper.com/transgender-dog-unsu...
# 3337  https://www.ncscooper.com/transgender-dog-unsu...
# 3338  https://www.ncscooper.com/transgender-dog-unsu...
#
#                            1
# 0     http://alertchild.com/
# 1     http://alertchild.com/
# 2     http://alertchild.com/
# 3     http://alertchild.com/
# 4     http://alertchild.com/
# ...                      ...
# 3334                    None
# 3335                    None
# ...

# %%
FakeNews1['Domain'] = FakeNews1[0] + " " + FakeNews1[1].map(str)

# %%
FakeNews1
# Out:
#                                                       0  \
# 0       http://wayback.archive.org/web/20161004072420id
# 1       http://wayback.archive.org/web/20161004072420id
# 2       http://wayback.archive.org/web/20161004072420id
# 3       http://wayback.archive.org/web/20161004072420id
# 4       http://wayback.archive.org/web/20161004072420id
# ...                                                 ...
# 3334  https://www.ncscooper.com/transgender-dog-unsu...
# 3335  https://www.ncscooper.com/transgender-dog-unsu...
# 3336  https://www.ncscooper.com/transgender-dog-unsu...
# 3337  https://www.ncscooper.com/transgender-dog-unsu...
# 3338  https://www.ncscooper.com/transgender-dog-unsu...
#
#                            1  \
# 0     http://alertchild.com/
# 1     http://alertchild.com/
# 2     http://alertchild.com/
# 3     http://alertchild.com/
# 4     http://alertchild.com/
# ...                      ...
# 3334                    None
# 3335                    None
# ...

# %%
FakeNews2 = FakeNews[:10]

# %%
FakeNews2
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 5  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 6  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 7  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 8  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
# 9  before-nov-2016  http://wayback.archive.org/web/20161001155200i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# ...
