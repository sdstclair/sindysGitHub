# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from pylab import *
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox
import warnings
warnings.filterwarnings('ignore')
from matplotlib import image
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import RegexpTokenizer
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split
import plotly.graph_objects as go
import chart_studio.plotly as py
from plotly.graph_objects import *

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
# Lesson 1

# %%
data_dictionary = pd.read_excel(r'C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\Data_Dictionary.xlsx')
first_health_camp = pd.read_csv(r"C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\First_Health_Camp_Attended.csv")
health_camp_details = pd.read_csv(r"C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\Health_Camp_Detail.csv")
patient_profile = pd.read_csv(r"C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\Patient_Profile.csv")
second_health_camp = pd.read_csv(r"C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\Second_Health_Camp_Attended.csv")
third_health_camp = pd.read_csv(r"C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\Third_Health_Camp_Attended.csv")
train = pd.read_csv(r"C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\Train.csv")
test = pd.read_csv(r"C:\Users\sdstc\Documents\Education\Other\Entity Academy\Portfolio\DSO104C Extra Portfolio Activities\Healthcare Analytics\Train\test.csv")

# %%
# Reading all the files

# %%
data_dictionary.head()
# Out:
#                                 Details of the Files
# 0  Health_Camp_Detail.csv – File containing Healt...
# 1  Train.csv – File containing registration detai...
# 2  Patient_Profile.csv – This file contains Patie...
# 3  First_Health_Camp_Attended.csv – This file con...
# 4  Second_Health_Camp_Attended.csv - This file co...

# %%
first_health_camp.head()
# Out:
#    Patient_ID  Health_Camp_ID  Donation  Health_Score  Unnamed: 4
# 0      506181            6560        40      0.439024         NaN
# 1      494977            6560        20      0.097561         NaN
# 2      518680            6560        10      0.048780         NaN
# 3      509916            6560        30      0.634146         NaN
# 4      488006            6560        20      0.024390         NaN

# %%
health_camp_details.head()
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  Category3
# 0            6560       16-Aug-03     20-Aug-03     First         B          2
# 1            6530       16-Aug-03     28-Oct-03     First         C          2
# 2            6544       03-Nov-03     15-Nov-03     First         F          1
# 3            6585       22-Nov-03     05-Dec-03     First         E          2
# 4            6561       30-Nov-03     18-Dec-03     First         E          1

# %%
patient_profile.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared Income Education_Score Age First_Interaction City_Type  \
# 0                0      1              90  39         18-Jun-03       NaN
# 1                0      1            None  40         20-Jul-03         H
# 2                0      3              87  46         02-Nov-02         D
# 3                0      1              75  47         02-Nov-02         D
# 4                0      3            None  80         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# 1  Software Industry
# 2               BFSI
# 3          Education
# 4             Others

# %%
second_health_camp.head()
# Out:
#    Patient_ID  Health_Camp_ID  Health Score
# 0      526631            6536      0.875136
# 1      509122            6536      0.755700
# 2      498864            6536      0.673181
# 3      515398            6536      0.722041
# 4      504624            6536      0.464712

# %%
third_health_camp.head()
# Out:
#    Patient_ID  Health_Camp_ID  Number_of_stall_visited  \
# 0      517875            6527                        3
# 1      504692            6578                        1
# 2      504692            6527                        3
# 3      493167            6527                        4
# 4      510954            6528                        2
#
#    Last_Stall_Visited_Number
# 0                          1
# 1                          1
# 2                          1
# 3                          4
# 4                          2

# %%
train.head()
# Out:
#    Patient_ID  Health_Camp_ID Registration_Date  Var1  Var2  Var3  Var4  Var5
# 0      489652            6578         10-Sep-05     4     0     0     0     2
# 1      507246            6578         18-Aug-05    45     5     0     0     7
# 2      523729            6534         29-Apr-06     0     0     0     0     0
# 3      524931            6535         07-Feb-04     0     0     0     0     0
# 4      521364            6529         28-Feb-06    15     1     0     0     7

# %%
# Lesson 2

# %%
patient_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37633 entries, 0 to 37632
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         37633 non-null  int64
#  1   Online_Follower    37633 non-null  int64
#  2   LinkedIn_Shared    37633 non-null  int64
#  3   Twitter_Shared     37633 non-null  int64
#  4   Facebook_Shared    37633 non-null  int64
#  5   Income             37633 non-null  object
#  6   Education_Score    37633 non-null  object
#  7   Age                37633 non-null  object
#  8   First_Interaction  37633 non-null  object
#  9   City_Type          14249 non-null  object
#  10  Employer_Category  2840 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 3.2+ MB

# %%
patient_profile.describe()
# Out:
#           Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# count   37633.000000     37633.000000     37633.000000    37633.000000
# mean   507148.408338         0.022533         0.027077        0.021603
# std     12411.747993         0.148412         0.162311        0.145387
# min    485678.000000         0.000000         0.000000        0.000000
# 25%    496393.000000         0.000000         0.000000        0.000000
# 50%    507104.000000         0.000000         0.000000        0.000000
# 75%    517882.000000         0.000000         0.000000        0.000000
# max    528657.000000         1.000000         1.000000        1.000000
#
#        Facebook_Shared
# count     37633.000000
# mean          0.023543
# std           0.151623
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000

# %%
# Merging these different dataframes into single dataframe for further analysis

# %%
merged_details = pd.merge(right = patient_profile, left = first_health_camp, on="Patient_ID")

merged_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218 entries, 0 to 6217
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         6218 non-null   int64
#  1   Health_Camp_ID     6218 non-null   int64
#  2   Donation           6218 non-null   int64
#  3   Health_Score       6218 non-null   float64
#  4   Unnamed: 4         0 non-null      float64
#  5   Online_Follower    6218 non-null   int64
#  6   LinkedIn_Shared    6218 non-null   int64
#  7   Twitter_Shared     6218 non-null   int64
#  8   Facebook_Shared    6218 non-null   int64
#  9   Income             6218 non-null   object
#  10  Education_Score    6218 non-null   object
#  11  Age                6218 non-null   object
#  12  First_Interaction  6218 non-null   object
#  13  City_Type          4451 non-null   object
#  14  Employer_Category  2300 non-null   object
# dtypes: float64(2), int64(7), object(6)
# ...

# %%
merged_details = merged_details.merge(health_camp_details, on = "Health_Camp_ID" )
merged_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218 entries, 0 to 6217
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         6218 non-null   int64
#  1   Health_Camp_ID     6218 non-null   int64
#  2   Donation           6218 non-null   int64
#  3   Health_Score       6218 non-null   float64
#  4   Unnamed: 4         0 non-null      float64
#  5   Online_Follower    6218 non-null   int64
#  6   LinkedIn_Shared    6218 non-null   int64
#  7   Twitter_Shared     6218 non-null   int64
#  8   Facebook_Shared    6218 non-null   int64
#  9   Income             6218 non-null   object
#  10  Education_Score    6218 non-null   object
#  11  Age                6218 non-null   object
#  12  First_Interaction  6218 non-null   object
#  13  City_Type          4451 non-null   object
#  14  Employer_Category  2300 non-null   object
#  15  Camp_Start_Date    6218 non-null   object
# ...

# %%
merged_details = merged_details.merge(second_health_camp, on="Patient_ID")
merged_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5212 entries, 0 to 5211
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         5212 non-null   int64
#  1   Health_Camp_ID_x   5212 non-null   int64
#  2   Donation           5212 non-null   int64
#  3   Health_Score       5212 non-null   float64
#  4   Unnamed: 4         0 non-null      float64
#  5   Online_Follower    5212 non-null   int64
#  6   LinkedIn_Shared    5212 non-null   int64
#  7   Twitter_Shared     5212 non-null   int64
#  8   Facebook_Shared    5212 non-null   int64
#  9   Income             5212 non-null   object
#  10  Education_Score    5212 non-null   object
#  11  Age                5212 non-null   object
#  12  First_Interaction  5212 non-null   object
#  13  City_Type          4470 non-null   object
#  14  Employer_Category  2948 non-null   object
#  15  Camp_Start_Date    5212 non-null   object
# ...

# %%
merged_details = merged_details.merge(third_health_camp, on="Patient_ID")

# %%
# Look at all the information present in the merged dataframe

# %%
merged_details.head()
# Out:
#    Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 0      494977              6560        20      0.097561         NaN
# 1      494977              6560        20      0.097561         NaN
# 2      494977              6560        20      0.097561         NaN
# 3      494977              6560        20      0.097561         NaN
# 4      494977              6585        60      0.733990         NaN
#
#    Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared Income  \
# 0                1                1               1                0      2
# 1                1                1               1                0      2
# 2                1                1               1                0      2
# 3                1                1               1                0      2
# 4                1                1               1                0      2
#
#    ... Camp_Start_Date Camp_End_Date Category1 Category2 Category3  \
# ...

# %%
merged_details.describe()
# Out:
#           Patient_ID  Health_Camp_ID_x     Donation  Health_Score  Unnamed: 4  \
# count    5422.000000       5422.000000  5422.000000   5422.000000         0.0
# mean   507208.149023       6551.725378    32.880856      0.525072         NaN
# std     12311.461570         17.691238    25.985824      0.281859         NaN
# min    485720.000000       6524.000000    10.000000      0.001667         NaN
# 25%    496138.000000       6538.000000    20.000000      0.296296         NaN
# 50%    507904.000000       6543.000000    30.000000      0.549327         NaN
# 75%    518043.000000       6570.000000    40.000000      0.756793         NaN
# max    528589.000000       6586.000000   280.000000      1.000000         NaN
#
#        Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared  \
# count      5422.000000      5422.000000     5422.000000      5422.000000
# mean          0.175028         0.204168        0.164515         0.155293
# ...

# %%
# Finding what all values are missing

# %%
merged_details.isna()
# Out:
#       Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 0          False             False     False         False        True
# 1          False             False     False         False        True
# 2          False             False     False         False        True
# 3          False             False     False         False        True
# 4          False             False     False         False        True
# ...          ...               ...       ...           ...         ...
# 5417       False             False     False         False        True
# 5418       False             False     False         False        True
# 5419       False             False     False         False        True
# 5420       False             False     False         False        True
# 5421       False             False     False         False        True
#
#       Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared  \
# ...

# %%
merged_details.isna().sum()
# Out:
# Patient_ID                      0
# Health_Camp_ID_x                0
# Donation                        0
# Health_Score                    0
# Unnamed: 4                   5422
# Online_Follower                 0
# LinkedIn_Shared                 0
# Twitter_Shared                  0
# Facebook_Shared                 0
# Income                          0
# Education_Score                 0
# Age                             0
# First_Interaction               0
# City_Type                     640
# Employer_Category            2042
# Camp_Start_Date                 0
# Camp_End_Date                   0
# Category1                       0
# Category2                       0
# Category3                       0
# Health_Camp_ID_y                0
# Health Score                    0
# Health_Camp_ID                  0
# Number_of_stall_visited         0
# Last_Stall_Visited_Number       0
# dtype: int64

# %%
missing_percent = merged_details.isna().sum().sort_values (ascending=False)/len(merged_details)
missing_percent * 100
# Out:
# Unnamed: 4                   100.000000
# Employer_Category             37.661380
# City_Type                     11.803762
# Patient_ID                     0.000000
# Number_of_stall_visited        0.000000
# Health_Camp_ID                 0.000000
# Health Score                   0.000000
# Health_Camp_ID_y               0.000000
# Category3                      0.000000
# Category2                      0.000000
# Category1                      0.000000
# Camp_End_Date                  0.000000
# Camp_Start_Date                0.000000
# First_Interaction              0.000000
# Health_Camp_ID_x               0.000000
# Age                            0.000000
# Education_Score                0.000000
# Income                         0.000000
# Facebook_Shared                0.000000
# Twitter_Shared                 0.000000
# LinkedIn_Shared                0.000000
# Online_Follower                0.000000
# Health_Score                   0.000000
# ...

# %%
# Since Unnamed: 4 is missing all the time, we will drop this column.

# %%
merged_details2 = merged_details.drop('Unnamed: 4', axis=1, inplace=True)

# %%
# Handling the missing data

# %%
merged_details.columns
# Out:
# Index(['Patient_ID', 'Health_Camp_ID_x', 'Donation', 'Health_Score',
#        'Online_Follower', 'LinkedIn_Shared', 'Twitter_Shared',
#        'Facebook_Shared', 'Income', 'Education_Score', 'Age',
#        'First_Interaction', 'City_Type', 'Employer_Category',
#        'Camp_Start_Date', 'Camp_End_Date', 'Category1', 'Category2',
#        'Category3', 'Health_Camp_ID_y', 'Health Score', 'Health_Camp_ID',
#        'Number_of_stall_visited', 'Last_Stall_Visited_Number'],
#       dtype='object')

# %%
imp_col = ['Patient_ID', 'Health_Camp_ID', 'Donation', 'Health_Score', 'Income', 'Camp_Start_Date', 'Camp_End_Date', 'Health Score', 'Number_of_stall_visited']
merged_details[imp_col]
# Out:
#       Patient_ID  Health_Camp_ID  Donation  Health_Score Income  \
# 0         494977            6578        20      0.097561      2
# 1         494977            6527        20      0.097561      2
# 2         494977            6578        20      0.097561      2
# 3         494977            6527        20      0.097561      2
# 4         494977            6578        60      0.733990      2
# ...          ...             ...       ...           ...    ...
# 5417      499996            6527        20      0.537037   None
# 5418      495949            6527        30      0.037037   None
# 5419      520328            6527        20      0.092593   None
# 5420      517824            6578        20      0.648148   None
# 5421      517824            6527        20      0.648148   None
#
#      Camp_Start_Date Camp_End_Date  Health Score  Number_of_stall_visited
# 0          16-Aug-03     20-Aug-03      0.673181                        5
# ...

# %%
# Because health score has 2 different columns, we will add them.

# %%
merged_details['health'] = merged_details['Health Score'] + merged_details['Health_Score']
merged_details['health']
# Out:
# 0       0.770742
# 1       0.770742
# 2       0.713388
# 3       0.713388
# 4       1.407171
#           ...
# 5417    1.123530
# 5418    0.790967
# 5419    0.645555
# 5420    1.258338
# 5421    1.258338
# Name: health, Length: 5422, dtype: float64

# %%
imp_cols_pred = ['Donation', 'health', 'Income', 'Number_of_stall_visited', 'Employer_Category', 'City_Type']

# %%
useful_details = merged_details[imp_cols_pred]
useful_details.head()
# Out:
#    Donation    health Income  Number_of_stall_visited Employer_Category  \
# 0        20  0.770742      2                        5         Transport
# 1        20  0.770742      2                        2         Transport
# 2        20  0.713388      2                        5         Transport
# 3        20  0.713388      2                        2         Transport
# 4        60  1.407171      2                        5         Transport
#
#   City_Type
# 0         H
# 1         H
# 2         H
# 3         H
# 4         H

# %%
useful_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5422 entries, 0 to 5421
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Donation                 5422 non-null   int64
#  1   health                   5422 non-null   float64
#  2   Income                   5422 non-null   object
#  3   Number_of_stall_visited  5422 non-null   int64
#  4   Employer_Category        3380 non-null   object
#  5   City_Type                4782 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 296.5+ KB

# %%
# The Employer Category has 28868 non-null values and city_type has 37110 non null values, both out of 40000.

# %%
useful_details['Employer_Category'].mode()
# Out:
# 0    Technology
# Name: Employer_Category, dtype: object

# %%
useful_details['City_Type'].mode()
# Out:
# 0    H
# Name: City_Type, dtype: object

# %%
# So the most frequent values in Employer_Category and City_Type are 'Technology' and 'F' respectively. So we will fill the null places with it.

# %%
useful_details.City_Type.fillna('F', inplace=True)

# %%
useful_details.Employer_Category.fillna('Technology', inplace = True)

# %%
useful_details.head()
# Out:
#    Donation    health Income  Number_of_stall_visited Employer_Category  \
# 0        20  0.770742      2                        5         Transport
# 1        20  0.770742      2                        2         Transport
# 2        20  0.713388      2                        5         Transport
# 3        20  0.713388      2                        2         Transport
# 4        60  1.407171      2                        5         Transport
#
#   City_Type
# 0         H
# 1         H
# 2         H
# 3         H
# 4         H

# %%
useful_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5422 entries, 0 to 5421
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Donation                 5422 non-null   int64
#  1   health                   5422 non-null   float64
#  2   Income                   5422 non-null   object
#  3   Number_of_stall_visited  5422 non-null   int64
#  4   Employer_Category        5422 non-null   object
#  5   City_Type                5422 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 296.5+ KB

# %%
useful_details.to_csv("C:/Users/sdstc/Documents/Education/Other/Entity Academy/Portfolio/DSO104C Extra Portfolio Activities/Healthcare Analytics/Excel Data/useful_details.csv")

# %%
# Lesson 3

# %%
useful_details.Employer_Category.value_counts()
# Out:
# Technology           3023
# Consulting            496
# Others                473
# Software Industry     396
# BFSI                  246
# Education             215
# Transport             137
# Retail                131
# Real Estate            93
# Health                 82
# Manufacturing          55
# Food                   35
# Broadcasting           21
# Telecom                19
# Name: Employer_Category, dtype: int64

# %%
useful_details.Number_of_stall_visited.value_counts()
# Out:
# 1    1192
# 5    1096
# 3    1049
# 2     816
# 6     738
# 4     507
# 7      21
# 0       3
# Name: Number_of_stall_visited, dtype: int64

# %%
useful_details.Donation.value_counts()
# Out:
# 20     1409
# 10     1125
# 30     1091
# 40      659
# 50      434
# 60      243
# 70      186
# 80       80
# 90       61
# 100      36
# 110      30
# 120      12
# 130       9
# 140       9
# 280       9
# 150       8
# 160       8
# 250       6
# 180       3
# 210       2
# 170       2
# Name: Donation, dtype: int64

# %%
def NumStallsVisited (series):
    if series == 0 : 
        return 0
    if series >= 1 : 
        return 1
useful_details['Stall Visited'] = useful_details['Number_of_stall_visited'].apply(NumStallsVisited)

# %%
useful_details.head()
# Out:
#    Donation    health Income  Number_of_stall_visited Employer_Category  \
# 0        20  0.770742      2                        5         Transport
# 1        20  0.770742      2                        2         Transport
# 2        20  0.713388      2                        5         Transport
# 3        20  0.713388      2                        2         Transport
# 4        60  1.407171      2                        5         Transport
#
#   City_Type  Stall Visited
# 0         H              1
# 1         H              1
# 2         H              1
# 3         H              1
# 4         H              1

# %%
useful_details.describe()
# Out:
#           Donation       health  Number_of_stall_visited  Stall Visited
# count  5422.000000  5422.000000              5422.000000    5422.000000
# mean     32.880856     1.132249                 3.329768       0.999447
# std      25.985824     0.407618                 1.765143       0.023518
# min      10.000000     0.077326                 0.000000       0.000000
# 25%      20.000000     0.844802                 2.000000       1.000000
# 50%      30.000000     1.147704                 3.000000       1.000000
# 75%      40.000000     1.432447                 5.000000       1.000000
# max     280.000000     1.985676                 7.000000       1.000000

# %%
# Lesson 4

# %%
useful_details.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Donation'}>,
#         <AxesSubplot:title={'center':'health'}>],
#        [<AxesSubplot:title={'center':'Number_of_stall_visited'}>,
#         <AxesSubplot:title={'center':'Stall Visited'}>]], dtype=object)

# %%
num_bins = 7

# %%
n, bins, patches = plt.hist(useful_details["Donation"], num_bins, facecolor='blue', alpha=.05)
plt.xlabel('Donation Amount')
plt.ylabel("Number of Patients that Donated")
plt.title('Histogram of Donations Made by Patients')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
EmployerCategoryFrq = useful_details.Employer_Category.value_counts().plot(kind='bar')
EmployerCategoryFrq.set_title("Employer Category Frequency")
EmployerCategoryFrq.set_xlabel("Employer Category")
EmployerCategoryFrq.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Lesson 5

# %%
corr = useful_details.corr()
corr
# Out:
#                          Donation    health  Number_of_stall_visited  \
# Donation                 1.000000  0.262977                -0.062058
# health                   0.262977  1.000000                 0.079815
# Number_of_stall_visited -0.062058  0.079815                 1.000000
# Stall Visited           -0.021539 -0.014936                 0.044389
#
#                          Stall Visited
# Donation                     -0.021539
# health                       -0.014936
# Number_of_stall_visited       0.044389
# Stall Visited                 1.000000

# %%
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
print(useful_details.corr())
  
# plotting correlation heatmap
ud_heatmap = sns.heatmap(useful_details.corr(), cmap="YlGnBu", annot=True)
# Out:
#                          Donation    health  Number_of_stall_visited  \
# Donation                 1.000000  0.262977                -0.062058
# health                   0.262977  1.000000                 0.079815
# Number_of_stall_visited -0.062058  0.079815                 1.000000
# Stall Visited           -0.021539 -0.014936                 0.044389
#
#                          Stall Visited
# Donation                     -0.021539
# health                       -0.014936
# Number_of_stall_visited       0.044389
# Stall Visited                 1.000000

# %%
for col in useful_details.columns:
    if useful_details[col].dtype == 'int64':
        plt.pie(useful_details[col].value_counts(), labels=useful_details[col].unique())
        plt.title('Piechart for {}'.format(col))
        plt.show()
    else:
        plt.hist(useful_details[col].value_counts())
        plt.title('Histogram for {}'.format(col))
        plt.show();

# %% [markdown]
# # From what we can see here, a majority of patients that visited the health camps and registered, made $20 donations and had health scores lower than 2.5. The top 3 number of times stalls were visited were once, twice, and five times. There were more visits to the stalls than there weren't by nearly 99%.

# %% [markdown]
# # Lesson 9: Now out of all the statistical analyses that would best fit with this dataset, stepwise Multinomial Logistic Regression and Multinomial Logistic Regression are the two analyses that should be run on this dataset and here are the reasons why:
#
# ## When it comes to drawing conclusions for continuous Independent Variables with categorical dependent variables, we must first evaluate how many levels are in our dependent variable.

# %% [markdown]
# # From the useful_details dataframe:
# # Independent variables include the number of stalls visited which ranges from 0-6
# # Dependent variables include city type, employer category, income, health, and donation amount.

# %% [markdown]
# ## In this case, there are more than two, so we can choose if we would like to know how much influence each variable has. If yes, than stepwise multinomial logistic regression is best. If not, then multinomial logistic regression would be preferable.
