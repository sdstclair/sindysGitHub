# %% [markdown]
# # DSO104 Data Wrangling and Visualization: Does Beauty Affect Wages?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
Beauty = pd.read_csv('C:/Users/sdstc/Documents/Education/Other/Entity Academy/Portfolio/DSO104C Extra Portfolio Acitivities/Beauty/beauty.csv')

# %%
Beauty
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0      5.73     30      0         1      0       1        1        1    14
# 1      4.28     28      0         1      0       1        1        0    12
# 2      7.96     35      0         1      0       1        0        0    10
# 3     11.57     38      0         1      0       0        1        1    16
# 4     11.42     27      0         1      0       0        1        0    16
# ...     ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1255   1.61     25      0         1      1       1        0        1    12
# 1256   1.68      4      0         1      0       1        1        1    12
# 1257   3.29     35      0         1      1       1        0        1    12
# 1258   2.31     15      0         1      1       1        1        1    10
# 1259   1.92     24      0         0      0       1        0        1    16
#
#       looks
# 0         4
# 1         3
# 2         4
# 3         3
# ...

# %% [markdown]
# ## Lesson 1: Rename or Add Columns

# %%
Beauty.rename(columns={'wage' : 'Wages'}, inplace=True)

# %%
Beauty.rename(columns={'exper' : 'Experience'}, inplace=True)

# %%
Beauty.rename(columns={'union' : 'Ties w/ Union'}, inplace=True)

# %%
Beauty.rename(columns={'goodhlth' : 'Good Health'}, inplace=True)

# %%
Beauty.rename(columns={'black' : 'Racially Black'}, inplace=True)

# %%
Beauty.rename(columns={'female' : 'Sex'}, inplace=True)

# %%
Beauty.rename(columns={'married' : 'Marital Status'}, inplace=True)

# %%
Beauty.rename(columns={'service' : 'Service'}, inplace=True)

# %%
Beauty.rename(columns={'educ': 'Education'}, inplace=True)

# %%
Beauty.rename(columns={'looks' : 'Appearance'}, inplace=True)

# %%
Beauty
# Out:
#       Wages  Experience  Ties w/ Union  Good Health  Racially Black  Sex  \
# 0      5.73          30              0            1               0    1
# 1      4.28          28              0            1               0    1
# 2      7.96          35              0            1               0    1
# 3     11.57          38              0            1               0    0
# 4     11.42          27              0            1               0    0
# ...     ...         ...            ...          ...             ...  ...
# 1255   1.61          25              0            1               1    1
# 1256   1.68           4              0            1               0    1
# 1257   3.29          35              0            1               1    1
# 1258   2.31          15              0            1               1    1
# 1259   1.92          24              0            0               0    1
#
#       Marital Status  Service  Education  Appearance
# ...

# %% [markdown]
# ## Lesson 2 Merging Datasets

# %%
LinkedIn = pd.read_csv("C:/Users/sdstc/Documents/Education/Other/Entity Academy/Portfolio/DSO104C Extra Portfolio Acitivities/Beauty/linkedin.csv")

# %%
LinkedIn.head()
# Out:
#    Unnamed: 0  avg_n_pos_per_prev_tenure  avg_pos_len  avg_prev_tenure_len  \
# 0           0                   2.000000        457.0               1338.0
# 1           1                   1.500000        212.0                897.5
# 2           2                   1.333333        243.0                669.0
# 3           3                   1.250000        123.0                562.5
# 4           4                   1.200000        244.0                474.6
#
#                       c_name                    m_urn  n_pos  n_prev_tenures  \
# 0                         TD  urn:li:member:149435456      1               1
# 1  Light Up The World (LUTW)  urn:li:member:149435456      1               2
# 2                    Glacier  urn:li:member:149435456      1               3
# 3                 Sprout App  urn:li:member:149435456      1               4
# 4                College Pro  urn:li:member:149435456      1               5
#
# ...

# %%
LinkedIn.rename(columns={'gender' : 'Sex'}, inplace=True)

# %%
LinkedIn.Sex
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#          ...
# 62704    Male
# 62705    Male
# 62706    Male
# 62707    Male
# 62708    Male
# Name: Sex, Length: 62709, dtype: object

# %%
def Sex_recode (series): 
    if series == "Female": 
        return 0
    if series == "Male": 
        return 1

LinkedIn['SexR'] = LinkedIn['Sex'].apply(Sex_recode)

# %%
LinkedIn.SexR
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 62704    1
# 62705    1
# 62706    1
# 62707    1
# 62708    1
# Name: SexR, Length: 62709, dtype: int64

# %%
LinkedIn.drop(['Sex'], axis=1, inplace = True)

# %%
result = LinkedIn.columns
print(result)
# Out:
# Index(['Unnamed: 0', 'avg_n_pos_per_prev_tenure', 'avg_pos_len',
#        'avg_prev_tenure_len', 'c_name', 'm_urn', 'n_pos', 'n_prev_tenures',
#        'tenure_len', 'age', 'beauty', 'beauty_female', 'beauty_male', 'blur',
#        'blur_gaussian', 'blur_motion', 'emo_anger', 'emo_disgust', 'emo_fear',
#        'emo_happiness', 'emo_neutral', 'emo_sadness', 'emo_surprise',
#        'ethnicity', 'face_quality', 'glass', 'head_pitch', 'head_roll',
#        'head_yaw', 'img', 'mouth_close', 'mouth_mask', 'mouth_open',
#        'mouth_other', 'skin_acne', 'skin_dark_circle', 'skin_health',
#        'skin_stain', 'smile', 'african', 'celtic_english', 'east_asian',
#        'european', 'greek', 'hispanic', 'jewish', 'muslim', 'nationality',
#        'nordic', 'south_asian', 'n_followers', 'SexR'],
#       dtype='object')

# %%
LinkedIn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62709 entries, 0 to 62708
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 62709 non-null  int64
#  1   avg_n_pos_per_prev_tenure  62709 non-null  float64
#  2   avg_pos_len                62709 non-null  float64
#  3   avg_prev_tenure_len        62709 non-null  float64
#  4   c_name                     62703 non-null  object
#  5   m_urn                      62709 non-null  object
#  6   n_pos                      62709 non-null  int64
#  7   n_prev_tenures             62709 non-null  int64
#  8   tenure_len                 62709 non-null  int64
#  9   age                        62709 non-null  int64
#  10  beauty                     62709 non-null  float64
#  11  beauty_female              62709 non-null  float64
#  12  beauty_male                62709 non-null  float64
# ...

# %%
LinkedIn
# Out:
#        Unnamed: 0  avg_n_pos_per_prev_tenure  avg_pos_len  \
# 0               0                   2.000000        457.0
# 1               1                   1.500000        212.0
# 2               2                   1.333333        243.0
# 3               3                   1.250000        123.0
# 4               4                   1.200000        244.0
# ...           ...                        ...          ...
# 62704       62704                   1.000000       3653.0
# 62705       62705                   1.000000       1277.0
# 62706       62706                   1.000000       1164.0
# 62707       62707                   1.750000       1035.0
# 62708       62708                   1.600000        273.0
#
#        avg_prev_tenure_len                     c_name  \
# 0              1338.000000                         TD
# 1               897.500000  Light Up The World (LUTW)
# 2               669.000000                    Glacier
# ...

# %%
LinkedIn.head()
# Out:
#    Unnamed: 0  avg_n_pos_per_prev_tenure  avg_pos_len  avg_prev_tenure_len  \
# 0           0                   2.000000        457.0               1338.0
# 1           1                   1.500000        212.0                897.5
# 2           2                   1.333333        243.0                669.0
# 3           3                   1.250000        123.0                562.5
# 4           4                   1.200000        244.0                474.6
#
#                       c_name                    m_urn  n_pos  n_prev_tenures  \
# 0                         TD  urn:li:member:149435456      1               1
# 1  Light Up The World (LUTW)  urn:li:member:149435456      1               2
# 2                    Glacier  urn:li:member:149435456      1               3
# 3                 Sprout App  urn:li:member:149435456      1               4
# 4                College Pro  urn:li:member:149435456      1               5
#
# ...

# %%
LinkedIn.rename(columns={'SexR' : 'Sex'}, inplace=True)

# %%
LinkedIn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62709 entries, 0 to 62708
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 62709 non-null  int64
#  1   avg_n_pos_per_prev_tenure  62709 non-null  float64
#  2   avg_pos_len                62709 non-null  float64
#  3   avg_prev_tenure_len        62709 non-null  float64
#  4   c_name                     62703 non-null  object
#  5   m_urn                      62709 non-null  object
#  6   n_pos                      62709 non-null  int64
#  7   n_prev_tenures             62709 non-null  int64
#  8   tenure_len                 62709 non-null  int64
#  9   age                        62709 non-null  int64
#  10  beauty                     62709 non-null  float64
#  11  beauty_female              62709 non-null  float64
#  12  beauty_male                62709 non-null  float64
# ...

# %%
Beauty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wages           1260 non-null   float64
#  1   Experience      1260 non-null   int64
#  2   Ties w/ Union   1260 non-null   int64
#  3   Good Health     1260 non-null   int64
#  4   Racially Black  1260 non-null   int64
#  5   Sex             1260 non-null   int64
#  6   Marital Status  1260 non-null   int64
#  7   Service         1260 non-null   int64
#  8   Education       1260 non-null   int64
#  9   Appearance      1260 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 98.6 KB

# %%
Beauty_LinkedIn = pd.merge(Beauty, LinkedIn, on='Sex')

# %%
Beauty_LinkedIn.head()
# Out:
#    Wages  Experience  Ties w/ Union  Good Health  Racially Black  Sex  \
# 0   5.73          30              0            1               0    1
# 1   5.73          30              0            1               0    1
# 2   5.73          30              0            1               0    1
# 3   5.73          30              0            1               0    1
# 4   5.73          30              0            1               0    1
#
#    Marital Status  Service  Education  Appearance  ...  east_asian  european  \
# 0               1        1         14           4  ...    0.877681   0.05267
# 1               1        1         14           4  ...    0.877681   0.05267
# 2               1        1         14           4  ...    0.877681   0.05267
# 3               1        1         14           4  ...    0.877681   0.05267
# 4               1        1         14           4  ...    0.877681   0.05267
#
#           greek  hispanic        jewish    muslim  nationality    nordic  \
# ...

# %%
Beauty_LinkedIn.columns
# Out:
# Index(['Wages', 'Experience', 'Ties w/ Union', 'Good Health', 'Racially Black',
#        'Sex', 'Marital Status', 'Service', 'Education', 'Appearance',
#        'Unnamed: 0', 'avg_n_pos_per_prev_tenure', 'avg_pos_len',
#        'avg_prev_tenure_len', 'c_name', 'm_urn', 'n_pos', 'n_prev_tenures',
#        'tenure_len', 'age', 'beauty', 'beauty_female', 'beauty_male', 'blur',
#        'blur_gaussian', 'blur_motion', 'emo_anger', 'emo_disgust', 'emo_fear',
#        'emo_happiness', 'emo_neutral', 'emo_sadness', 'emo_surprise',
#        'ethnicity', 'face_quality', 'glass', 'head_pitch', 'head_roll',
#        'head_yaw', 'img', 'mouth_close', 'mouth_mask', 'mouth_open',
#        'mouth_other', 'skin_acne', 'skin_dark_circle', 'skin_health',
#        'skin_stain', 'smile', 'african', 'celtic_english', 'east_asian',
#        'european', 'greek', 'hispanic', 'jewish', 'muslim', 'nationality',
#        'nordic', 'south_asian', 'n_followers'],
#       dtype='object')

# %% [markdown]
# ## Lesson 3 Recoding Continuous Variable Column into String Column

# %%
def age_recode (series): 
    if series < 18:
        return "minor"
    if series > 18: 
        return "adult"
    if series > 55: 
        return "senior"
 
Beauty_LinkedIn['ageR'] = Beauty_LinkedIn['age'].apply(age_recode)

# %%
Beauty_LinkedIn.ageR
# Out:
# 0           adult
# 1           adult
# 2           adult
# 3           adult
# 4           adult
#             ...
# 33132019    adult
# 33132020    adult
# 33132021    adult
# 33132022    adult
# 33132023    adult
# Name: ageR, Length: 33132024, dtype: object

# %%
Beauty_LinkedIn.head()
# Out:
#    Wages  Experience  Ties w/ Union  Good Health  Racially Black  Sex  \
# 0   5.73          30              0            1               0    1
# 1   5.73          30              0            1               0    1
# 2   5.73          30              0            1               0    1
# 3   5.73          30              0            1               0    1
# 4   5.73          30              0            1               0    1
#
#    Marital Status  Service  Education  Appearance  ...  european  \
# 0               1        1         14           4  ...   0.05267
# 1               1        1         14           4  ...   0.05267
# 2               1        1         14           4  ...   0.05267
# 3               1        1         14           4  ...   0.05267
# 4               1        1         14           4  ...   0.05267
#
#           greek  hispanic        jewish    muslim nationality    nordic  \
# 0  3.170000e-08  0.000638  2.100000e-08  0.000001  east_asian  0.008284
# ...

# %%
Beauty_LinkedIn.drop(['age'], axis=1, inplace = True)

# %%
Beauty_LinkedIn.head()
# Out:
#    Wages  Experience  Ties w/ Union  Good Health  Racially Black  Sex  \
# 0   5.73          30              0            1               0    1
# 1   5.73          30              0            1               0    1
# 2   5.73          30              0            1               0    1
# 3   5.73          30              0            1               0    1
# 4   5.73          30              0            1               0    1
#
#    Marital Status  Service  Education  Appearance  ...  european  \
# 0               1        1         14           4  ...   0.05267
# 1               1        1         14           4  ...   0.05267
# 2               1        1         14           4  ...   0.05267
# 3               1        1         14           4  ...   0.05267
# 4               1        1         14           4  ...   0.05267
#
#           greek  hispanic        jewish    muslim nationality    nordic  \
# 0  3.170000e-08  0.000638  2.100000e-08  0.000001  east_asian  0.008284
# ...

# %%
Beauty_LinkedIn.rename(columns={'ageR' : 'Age'}, inplace=True)

# %%
Beauty_LinkedIn.Age
# Out:
# 0           adult
# 1           adult
# 2           adult
# 3           adult
# 4           adult
#             ...
# 33132019    adult
# 33132020    adult
# 33132021    adult
# 33132022    adult
# 33132023    adult
# Name: Age, Length: 33132024, dtype: object

# %% [markdown]
# ## Lesson 4: (a) Choose a continuous variable column and create a histogram. (b) Then choose a categorical variable column and create a bar chart.

# %% [markdown]
# ### (A)

# %%
Beauty_LinkedIn.Appearance
# Out:
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
#            ..
# 33132019    3
# 33132020    3
# 33132021    3
# 33132022    3
# 33132023    3
# Name: Appearance, Length: 33132024, dtype: int64

# %%
num_bins = 4

# %%
n, bins, patches = plt.hist(Beauty_LinkedIn['Appearance'], num_bins, facecolor='blue', alpha=1)
plt.xlabel('Appearance')
plt.ylabel('Frequency')
plt.title('Histogram of Appearance Level and Frequency')
# Out:
# Text(0.5, 1.0, 'Histogram of Appearance Level and Frequency')

# %% [markdown]
# ### (B)

# %%
Beauty_LinkedIn.nationality
# Out:
# 0               east_asian
# 1               east_asian
# 2               east_asian
# 3               east_asian
# 4               east_asian
#                  ...
# 33132019       south_asian
# 33132020       south_asian
# 33132021          european
# 33132022          european
# 33132023    celtic_english
# Name: nationality, Length: 33132024, dtype: object

# %%
NationFreq = Beauty_LinkedIn['nationality'].value_counts().plot(kind='bar')
NationFreq.set_title("How Often Each Nationality Has Been Recorded for this Study?")
NationFreq.set_xlabel("Nationality")
NationFreq.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Lesson 5: Choose a dataset that has 3 or more continuous variables and create a correlation heatmap.

# %%
print(Beauty_LinkedIn.corr())
# Out:
#                               Wages  Experience  Ties w/ Union  Good Health  \
# Wages                      1.000000    0.210307       0.148865     0.024661
# Experience                 0.210307    1.000000       0.108471    -0.142430
# Ties w/ Union              0.148865    0.108471       1.000000    -0.016267
# Good Health                0.024661   -0.142430      -0.016267     1.000000
# Racially Black            -0.001249    0.008182       0.015642    -0.031771
# Sex                       -0.327117   -0.261318      -0.105036    -0.038757
# Marital Status             0.146742    0.188959       0.058571    -0.016389
# Service                   -0.025478   -0.051453      -0.065731     0.064019
# Education                  0.210542   -0.155907      -0.036975     0.109176
# Appearance                 0.060580   -0.150941      -0.057344     0.047773
# Unnamed: 0                 0.000868    0.000693       0.000279     0.000103
# ...

# %%
B_Lplot=sns.heatmap(Beauty_LinkedIn.corr())
